# %% [markdown]
# # Hypothesis Testing

# %%
import numpy as np
import pandas as pd

mutual_fund_data = pd.read_csv("Top100MutualFunds.csv")
mutual_fund_data
# Out:
#    Symbol                                               Name  Category1  \
# 0   AGTHX  American Funds The Growth Fund of America Class A  US Equity
# 1   FCNTX                           Fidelity Contrafund Fund  US Equity
# 2   CWMAX  American Funds Washington Mutual Investors Fun...  US Equity
# 3   CWMCX  American Funds Washington Mutual Investors Fun...  US Equity
# 4   CWMEX  American Funds Washington Mutual Investors Fun...  US Equity
# ..    ...                                                ...        ...
# 95  FDTRX                    Franklin DynaTech Fund Class R6  US Equity
# 96  FDYZX               Franklin DynaTech Fund Advisor Class  US Equity
# 97  BBVLX                Bridge Builder Large Cap Value Fund  US Equity
# 98  PEYAX                Putnam Large Cap Value Fund Class A  US Equity
# 99  TWCGX        American Century Growth Fund Investor Class  US Equity
#
#        Category2  Category3 Morningstar Category  Morningstar Rating  \
# 0   Broad market  Large cap         Large Growth                 3.0
# 1   Broad market  Large cap         Large Growth                 3.0
# 2   Broad market  Large cap          Large Blend                 3.0
# 3   Broad market  Large cap          Large Blend                 3.0
# 4   Broad market  Large cap          Large Blend                 3.0
# ..           ...        ...                  ...                 ...
# 95  Broad market  Large cap         Large Growth                 5.0
# 96  Broad market  Large cap         Large Growth                 5.0
# 97  Broad market  Large cap          Large Value                 4.0
# 98  Broad market  Large cap          Large Value                 4.0
# 99  Broad market  Large cap         Large Growth                 3.0
#
#           Market cap Current yield   Fees   Action
# 0   $138,592,080,000         0.22%  0.62%  Analyze
# 1   $121,762,870,000         0.00%  0.74%  Analyze
# 2   $113,300,000,000         1.46%  0.63%  Analyze
# 3   $113,300,000,000         0.79%  1.40%  Analyze
# 4   $113,300,000,000         1.28%  0.87%  Analyze
# ..               ...           ...    ...      ...
# 95    $9,600,000,000         0.00%  0.51%  Analyze
# 96    $9,600,000,000         0.00%  0.62%  Analyze
# 97    $9,500,000,000         1.55%  0.25%  Analyze
# 98    $9,393,340,000         1.23%  0.91%  Analyze
# 99    $9,354,900,000         0.00%  0.98%  Analyze
#
# [100 rows x 11 columns]

# %%
mutual_fund_data["Morningstar Category"].value_counts()
# Out:
# Large Growth      51
# Large Value       20
# Large Blend       17
# Mid-Cap Growth     6
# Mid-Cap Value      2
# Health             1
# Mid-Cap Blend      1
# Communications     1
# Small Value        1
# Name: Morningstar Category, dtype: int64

# %%
mutual_fund_data.groupby("Morningstar Category").mean()
# Out:
# C:\Users\hthog\AppData\Local\Temp\ipykernel_20900\4064092969.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mutual_fund_data.groupby("Morningstar Category").mean()
#                       Morningstar Rating
# Morningstar Category
# Communications                  5.000000
# Health                          5.000000
# Large Blend                     3.250000
# Large Growth                    3.755102
# Large Value                     3.750000
# Mid-Cap Blend                   4.000000
# Mid-Cap Growth                  4.333333
# Mid-Cap Value                   3.000000
# Small Value                     4.000000

# %%
mutual_fund_data["Morningstar Rating"].value_counts(normalize = True)
# Out:
# 3.0    0.432990
# 4.0    0.350515
# 5.0    0.195876
# 2.0    0.020619
# Name: Morningstar Rating, dtype: float64

# %%
import pandas_datareader.data as web
import yfinance as yf
from datetime import datetime

mutual_fund_dict = {}
symbols = list(mutual_fund_data["Symbol"])

start = datetime(1980, 1, 1)
end = datetime(2020, 1, 1)
print(start, end, symbols)
# Out:
# 1980-01-01 00:00:00 2020-01-01 00:00:00 ['AGTHX', 'FCNTX', 'CWMAX', 'CWMCX', 'CWMEX', 'CWMFX', 'AIVSX', 'AWSHX', 'ANCFX', 'AMCFX', 'CAFAX', 'CAFCX', 'CAFEX', 'CAFFX', 'FMACX', 'TRBCX', 'AFMFX', 'AMRFX', 'CMLAX', 'CMLCX', 'CMLEX', 'CMLFX', 'FDGRX', 'FBGRX', 'AMCPX', 'EAGRX', 'AMRMX', 'FMAGX', 'HACAX', 'FLPSX', 'PRGFX', 'PRNHX', 'DFQTX', 'DFEOX', 'FLPKX', 'RPMGX', 'FOCPX', 'CNGAX', 'CNGCX', 'CNGEX', 'CNGFX', 'FNEFX', 'FOCKX', 'DFLVX', 'CDDRX', 'CDDYX', 'CDIRX', 'CVIRX', 'TWCUX', 'EGFFX', 'EGFIX', 'ANEFX', 'HLIEX', 'FRDPX', 'FRDAX', 'FRDRX', 'FRISX', 'PRHSX', 'PRILX', 'DDFIX', 'DDFRX', 'VAFAX', 'PCBIX', 'FCGAX', 'FGSRX', 'FIFRX', 'PRFDX', 'PRBLX', 'JVMIX', 'VWNFX', 'FKGRX', 'PRDGX', 'AULDX', 'AULGX', 'AULNX', 'AULRX', 'AULYX', 'AKRSX', 'MFEIX', 'POLIX', 'FKDNX', 'MADVX', 'VWUSX', 'LSGRX', 'SEEGX', 'PRMTX', 'CUSUX', 'ERASX', 'ERSMX', 'DFSVX', 'CMGIX', 'SBLYX', 'AKRIX', 'MFEGX', 'FDNRX', 'FDTRX', 'FDYZX', 'BBVLX', 'PEYAX', 'TWCGX']

# %%
yf.pdr_override()
fund_data = web.get_data_yahoo(symbols, start, end)
# Out:
# [*********************100%***********************]  100 of 100 completed
#
# 1 Failed download:
# - TWCGX: No data found, symbol may be delisted

# %%
close_data = fund_data["Adj Close"]
close_data
# Out:
#                 AFMFX      AGTHX      AIVSX      AKRIX      AKRSX      AMCFX  \
# Date
# 1980-01-02        NaN   0.644044        NaN        NaN        NaN        NaN
# 1980-01-03        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-04        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-07        NaN   0.672127        NaN        NaN        NaN        NaN
# 1980-01-08        NaN   0.679616        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  38.097603  43.498634  33.953678  41.269047  41.468193  28.316502
# 2019-12-26  38.185299  43.719616  34.099621  41.387012  41.586231  28.408522
# 2019-12-27  38.211617  43.711117  34.099621  41.441452  41.640713  28.400156
# 2019-12-30  38.062519  43.328651  33.867836  41.296268  41.486351  28.216122
# 2019-12-31  38.150219  43.456142  33.970852  41.387012  41.586231  28.283043
#
#                 AMCPX      AMRFX      AMRMX      ANCFX  ...      PRNHX  \
# Date                                                    ...
# 1980-01-02        NaN        NaN        NaN   0.723485  ...   0.599537
# 1980-01-03        NaN        NaN        NaN   0.719449  ...   0.588704
# 1980-01-04        NaN        NaN        NaN   0.730548  ...   0.595768
# 1980-01-07        NaN        NaN        NaN   0.733576  ...   0.580032
# 1980-01-08        NaN        NaN        NaN   0.751739  ...   0.586269
# ...               ...        ...        ...        ...  ...        ...
# 2019-12-24  28.111412  38.230675  38.514614  51.184910  ...  42.597168
# 2019-12-26  28.203421  38.318687  38.603237  51.416256  ...  42.654209
# 2019-12-27  28.186689  38.345089  38.629814  51.465824  ...  42.504475
# 2019-12-30  28.002682  38.195473  38.479160  51.110542  ...  42.190731
# 2019-12-31  28.077957  38.283489  38.567787  51.242744  ...  42.333340
#
#                 RPMGX      SBLYX      SEEGX       TRBCX  TWCGX      TWCUX  \
# Date
# 1980-01-02        NaN        NaN        NaN         NaN    NaN        NaN
# 1980-01-03        NaN        NaN        NaN         NaN    NaN        NaN
# 1980-01-04        NaN        NaN        NaN         NaN    NaN        NaN
# 1980-01-07        NaN        NaN        NaN         NaN    NaN        NaN
# 1980-01-08        NaN        NaN        NaN         NaN    NaN        NaN
# ...               ...        ...        ...         ...    ...        ...
# 2019-12-24  80.298599  43.188065  32.569069  106.341019    NaN  43.968906
# 2019-12-26  80.374329  43.536552  32.785183  107.248009    NaN  44.383232
# 2019-12-27  80.290184  43.512787  32.761173  107.316467    NaN  44.357864
# 2019-12-30  79.987267  43.148468  32.449009  106.323914    NaN  43.994270
# 2019-12-31  80.214462  43.251427  32.521042  106.400917    NaN  44.104195
#
#                 VAFAX      VWNFX      VWUSX
# Date
# 1980-01-02        NaN        NaN   1.501897
# 1980-01-03        NaN        NaN   1.501897
# 1980-01-04        NaN        NaN   1.501897
# 1980-01-07        NaN        NaN   1.501897
# 1980-01-08        NaN        NaN   1.501897
# ...               ...        ...        ...
# 2019-12-24  14.698989  29.131344  36.265896
# 2019-12-26  14.812883  29.243481  36.535660
# 2019-12-27  14.819583  29.243481  36.501934
# 2019-12-30  14.698989  29.091295  36.147877
# 2019-12-31  14.732488  29.163383  36.265896
#
# [10087 rows x 100 columns]

# %%
close_data["S&P 500"] = web.get_data_yahoo('^GSPC', start, end)["Adj Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\hthog\AppData\Local\Temp\ipykernel_20900\3518298657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_data["S&P 500"] = web.get_data_yahoo('^GSPC', start, end)["Adj Close"]

# %%
close_data
# Out:
#                 AFMFX      AGTHX      AIVSX      AKRIX      AKRSX      AMCFX  \
# Date
# 1980-01-02        NaN   0.644044        NaN        NaN        NaN        NaN
# 1980-01-03        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-04        NaN   0.655277        NaN        NaN        NaN        NaN
# 1980-01-07        NaN   0.672127        NaN        NaN        NaN        NaN
# 1980-01-08        NaN   0.679616        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  38.097603  43.498634  33.953678  41.269047  41.468193  28.316502
# 2019-12-26  38.185299  43.719616  34.099621  41.387012  41.586231  28.408522
# 2019-12-27  38.211617  43.711117  34.099621  41.441452  41.640713  28.400156
# 2019-12-30  38.062519  43.328651  33.867836  41.296268  41.486351  28.216122
# 2019-12-31  38.150219  43.456142  33.970852  41.387012  41.586231  28.283043
#
#                 AMCPX      AMRFX      AMRMX      ANCFX  ...      RPMGX  \
# Date                                                    ...
# 1980-01-02        NaN        NaN        NaN   0.723485  ...        NaN
# 1980-01-03        NaN        NaN        NaN   0.719449  ...        NaN
# 1980-01-04        NaN        NaN        NaN   0.730548  ...        NaN
# 1980-01-07        NaN        NaN        NaN   0.733576  ...        NaN
# 1980-01-08        NaN        NaN        NaN   0.751739  ...        NaN
# ...               ...        ...        ...        ...  ...        ...
# 2019-12-24  28.111412  38.230675  38.514614  51.184910  ...  80.298599
# 2019-12-26  28.203421  38.318687  38.603237  51.416256  ...  80.374329
# 2019-12-27  28.186689  38.345089  38.629814  51.465824  ...  80.290184
# 2019-12-30  28.002682  38.195473  38.479160  51.110542  ...  79.987267
# 2019-12-31  28.077957  38.283489  38.567787  51.242744  ...  80.214462
#
#                 SBLYX      SEEGX       TRBCX  TWCGX      TWCUX      VAFAX  \
# Date
# 1980-01-02        NaN        NaN         NaN    NaN        NaN        NaN
# 1980-01-03        NaN        NaN         NaN    NaN        NaN        NaN
# 1980-01-04        NaN        NaN         NaN    NaN        NaN        NaN
# 1980-01-07        NaN        NaN         NaN    NaN        NaN        NaN
# 1980-01-08        NaN        NaN         NaN    NaN        NaN        NaN
# ...               ...        ...         ...    ...        ...        ...
# 2019-12-24  43.188065  32.569069  106.341019    NaN  43.968906  14.698989
# 2019-12-26  43.536552  32.785183  107.248009    NaN  44.383232  14.812883
# 2019-12-27  43.512787  32.761173  107.316467    NaN  44.357864  14.819583
# 2019-12-30  43.148468  32.449009  106.323914    NaN  43.994270  14.698989
# 2019-12-31  43.251427  32.521042  106.400917    NaN  44.104195  14.732488
#
#                 VWNFX      VWUSX      S&P 500
# Date
# 1980-01-02        NaN   1.501897   105.760002
# 1980-01-03        NaN   1.501897   105.220001
# 1980-01-04        NaN   1.501897   106.519997
# 1980-01-07        NaN   1.501897   106.809998
# 1980-01-08        NaN   1.501897   108.949997
# ...               ...        ...          ...
# 2019-12-24  29.131344  36.265896  3223.379883
# 2019-12-26  29.243481  36.535660  3239.909912
# 2019-12-27  29.243481  36.501934  3240.020020
# 2019-12-30  29.091295  36.147877  3221.290039
# 2019-12-31  29.163383  36.265896  3230.780029
#
# [10087 rows x 101 columns]

# %%
import matplotlib.pyplot as plt

yoy_return = np.log(close_data).diff(251)
fig, ax = plt.subplots(figsize = (20,10))
yoy_return.plot.line(legend = False, color = "k", alpha = 0.05, ax =ax)
ax.axhline(0, ls="--", color = "C2", linewidth = 1)
yoy_return["S&P 500"].plot.line(color = "Red", linewidth = 2, ax = ax)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
norm_data = close_data.div(close_data.iloc[0])
fig, ax = plt.subplots(figsize = (20,10))
norm_data.plot.line(legend=False, color = "k", alpha = 0.1, ax=ax)
ax.axhline(0, ls = "--", color = "k", linewidth = 2)
ax.axvline("2003", ls="--", color = "k", linewidth = 5)

norm_data["S&P 500"].plot.line(color="Red", linewidth = 2, ax = ax)
plt.rcParams.update({"font.size": 32})
ax.set_title("Index Returns Relative to Market Return")
# Out:
# Text(0.5, 1.0, 'Index Returns Relative to Market Return')

# %% [markdown]
# # Hypothesis Testing and Confidence Intervals

# %%
def t_value_isamp(data, mu):
    x_bar = np.mean(data)
    s = np.std(data)
    n = len(data)
    df = n - 1
    t = (x_bar - mu) / (s / np.sqrt(n))
    
    #return both t and df
    return t, df

# %%
close_data.index = pd.to_datetime(close_data.index)

monthly_close_data = close_data.resample("M").first()
monthly_returns = np.log(monthly_close_data).diff()
monthly_returns
# Out:
#                AFMFX     AGTHX     AIVSX     AKRIX     AKRSX     AMCFX  \
# Date
# 1980-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 1980-02-29       NaN  0.110001       NaN       NaN       NaN       NaN
# 1980-03-31       NaN -0.021054       NaN       NaN       NaN       NaN
# 1980-04-30       NaN -0.130496       NaN       NaN       NaN       NaN
# 1980-05-31       NaN  0.015037       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-08-31 -0.005503 -0.012487 -0.008626  0.016176  0.016344 -0.015695
# 2019-09-30  0.001678 -0.024837 -0.017747  0.021170  0.021095 -0.021001
# 2019-10-31  0.012995 -0.003892  0.005881 -0.015392 -0.015117 -0.005081
# 2019-11-30  0.023497  0.051211  0.038718  0.021699  0.021619  0.046650
# 2019-12-31  0.013150  0.025606  0.022079 -0.002171 -0.001946  0.027572
#
#                AMCPX     AMRFX     AMRMX     ANCFX  ...     RPMGX     SBLYX  \
# Date                                                ...
# 1980-01-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1980-02-29       NaN       NaN       NaN  0.089333  ...       NaN       NaN
# 1980-03-31       NaN       NaN       NaN -0.044104  ...       NaN       NaN
# 1980-04-30       NaN       NaN       NaN -0.074212  ...       NaN       NaN
# 1980-05-31       NaN       NaN       NaN  0.017291  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-08-31 -0.016124 -0.005741 -0.005979 -0.009414  ... -0.004088  0.003006
# 2019-09-30 -0.021167  0.001438  0.001438 -0.022891  ... -0.019086 -0.027967
# 2019-10-31 -0.005122  0.012953  0.012672  0.012289  ... -0.008925  0.003659
# 2019-11-30  0.046403  0.023497  0.023254  0.051054  ...  0.032204  0.038836
# 2019-12-31  0.027498  0.012922  0.012689  0.022516  ...  0.020805  0.020680
#
#                SEEGX     TRBCX  TWCGX     TWCUX     VAFAX     VWNFX     VWUSX  \
# Date
# 1980-01-31       NaN       NaN    NaN       NaN       NaN       NaN       NaN
# 1980-02-29       NaN       NaN    NaN       NaN       NaN       NaN  0.028005
# 1980-03-31       NaN       NaN    NaN       NaN       NaN       NaN -0.025019
# 1980-04-30       NaN       NaN    NaN       NaN       NaN       NaN -0.098594
# 1980-05-31       NaN       NaN    NaN       NaN       NaN       NaN  0.041874
# ...              ...       ...    ...       ...       ...       ...       ...
# 2019-08-31  0.005347 -0.000598    NaN  0.001625  0.002813 -0.005562 -0.003611
# 2019-09-30 -0.003484 -0.021066    NaN -0.026114 -0.013670 -0.025132 -0.019976
# 2019-10-31 -0.034319 -0.015653    NaN  0.005195 -0.007623  0.022619 -0.013127
# 2019-11-30  0.023558  0.039023    NaN  0.052288  0.051269  0.052285  0.043183
# 2019-12-31  0.036485  0.027408    NaN  0.030032  0.022018  0.016316  0.027786
#
#              S&P 500
# Date
# 1980-01-31       NaN
# 1980-02-29  0.084803
# 1980-03-31 -0.023022
# 1980-04-30 -0.096217
# 1980-05-31  0.031596
# ...              ...
# 2019-08-31 -0.003640
# 2019-09-30 -0.016141
# 2019-10-31  0.011624
# 2019-11-30  0.042176
# 2019-12-31  0.015196
#
# [480 rows x 101 columns]

# %%
sp500 = monthly_returns["S&P 500"].dropna()
sp500
# Out:
# Date
# 1980-02-29    0.084803
# 1980-03-31   -0.023022
# 1980-04-30   -0.096217
# 1980-05-31    0.031596
# 1980-06-30    0.049034
#                 ...
# 2019-08-31   -0.003640
# 2019-09-30   -0.016141
# 2019-10-31    0.011624
# 2019-11-30    0.042176
# 2019-12-31    0.015196
# Freq: M, Name: S&P 500, Length: 479, dtype: float64

# %%
sp500.mean() * 12
# Out:
# 0.08473776816463623

# %%
hypothesized_rate = .07 / 12

# %%
t_value_isamp(data = sp500, mu = hypothesized_rate)
# Out:
# (0.6072595645765044, 478)

# %%
import scipy.stats as stats
stats.ttest_1samp(sp500, hypothesized_rate)
# Out:
# Ttest_1sampResult(statistic=0.6066253507590067, pvalue=0.5443875720700815)

# %%
def t_value_ind_samp(a, b, hypothesized_difference=0, equal_var=False):
    
    a = np.array(a)
    b = np.array(b)
    
    s1, n1 = np.var(a) , len(a)
    s2, n2 = np.var(b),  len(b)
    
    # if paired samples, df calculation is different
    if (equal_var):
        df = n1 + n2 - 2
        svar = ((n1 - 1) * s1 + (n2 - 1) * s2) / float(df)
        denom = np.sqrt(svar * (1.0 / n1 + 1.0 / n2))
    else:
        vn1 = s1 / n1
        vn2 = s2 / n2
        df = (vn1 + vn2)**2 / (vn1**2 / (n1 - 1) + vn2**2 / (n2 - 1))
        denom = np.sqrt(vn1 + vn2)

    d = np.mean(a) - np.mean(b) - hypothesized_difference
    t = d / denom
    return t, df

# %%
prgfx = monthly_returns["PRGFX"].dropna()
sp500.mean(), prgfx.mean()
# Out:
# (0.0070614806803863525, 0.007124728902832503)

# %%
t_value_ind_samp(sp500, prgfx)
# Out:
# (-0.021224969913397222, 950.1085514690533)

# %%
import scipy.special as sc

def t_distribution(df, t):
    t_dist_val = ((1 + t**2 / df)**(-(df + 1) / 2)) / (sc.beta(.5, .5 * df) * np.sqrt(df))
    return t_dist_val

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 8))

x = np.linspace(-5, 5, 1000)
cauchy = t_distribution(1, x)
ax.plot(cauchy, '-', lw=3, alpha=1, label="Cauchy", color='b')
t_df = [2, 3, 4, 5, 10, 20]
for df in t_df:
    dist = t_distribution(df, x)
    ax.plot(dist, '-', lw=1, alpha=df / 20, label="df: " + str(df), color='k')
gaussian = t_distribution(30, x)
ax.plot(gaussian,
        lw=3,
        alpha=1,
        color='r',
        label='Standard Normal Distribution')
plt.rcParams.update({"font.size": 15})
ax.set_ylabel("Probability of t-score")
ax.set_xlabel(
    "Standard Deviations away from mean( this varies as the distributions have different SD's)"
)
plt.title("T-distribution with varying degrees of freedom")
ax.set_xticklabels(labels="")
plt.legend()

# %%
fig, ax = plt.subplots(figsize = (15,8))

#create t distributions w/ 30 df and 1 df
x = np.linspace(-5, 5, 1000)
t_dist = t_distribution(30, x)
cauchy = t_distribution(1, x)

#go along the linspace that was created and add current value to all previous values
f_dist = t_dist.copy()
cauchy_f_dist = cauchy.copy()

for i in range(len(t_dist)): 
    f_dist[i] += f_dist[i-1]
    cauchy_f_dist[i] += cauchy_f_dist[i-1]

ax.plot(x, f_dist, label = 't CDF distribution with 30 df')
ax.plot(x, cauchy_f_dist, label = 'Cauchy CDF distribution')

plt.legend()

# %%
def t_test(a, b, kind):
    
    if kind == 'one_sample': 
            t_val, df = t_value_isamp(a, b)
            print (t_val, df)
    elif kind  == 'independent': 
            t_val, df = t_value_ind_samp(a, b)
    elif kind == 'paired': 
            t_val, df = t_value_ind_samp(a, b, equal_var=True)
            
    # cdf gives probability of a value at least as extreme as observed happening; for two-sided tests this is doubled
    p_value = (1-stats.t.cdf(np.abs(t_val), df-1))  *2
    
    if p_value > .05:
        return_string = "T-value: " + str(t_val) + ", P-value: " + str(
            p_value) + ", Fail to reject null hypothesis."
    else:
        return_string = "T-value: " + str(t_val) + ", P-value: " + str(
            round(p_value, 5)) + ", Reject null hypothesis."
        
    return return_string

# %%
hypothesized_rate = .07/12
t_test(sp500, hypothesized_rate, "one_sample")
# Out:
# 0.6072595645765044 478
# 'T-value: 0.6072595645765044, P-value: 0.5439676244389173, Fail to reject null hypothesis.'

# %% [markdown]
# # Testing for Normality

# %%
from stats import *
def jarque_bera_test(series, use_sample_ks = False):
    series.dropna(inplace=True)
    n = series.shape[0]
    
    k = kurtosis(series, sample = use_sample_ks)
    s = skewness(series, sample = use_sample_ks)
    t = n / 6 * (s**2 + (k - 3) ** 2 / 4)
    
    df = n-1
    print(k, s, t)
    p = scipy.stats.t.sf(t, df = df)
    return t, p

# %%
from statsmodels.stats.stattools import jarque_bera
import scipy
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime
import numpy as np

start = datetime(2012, 1 , 1)
end = datetime.today()

stock_data = {}
stocks = ["MSFT", "AAPL", "PG", "TSLA", '^GSPC']
for key in stocks:
    stock_data[key] = web.DataReader(key, start, end, 'yahoo')["Close"]
stock_data = pd.DataFrame(stock_data).rename(columns = {"^GSPC":"S&P500"})
price_change_data = np.log(stock_data).diff()
price_change_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                 MSFT      AAPL        PG      TSLA    S&P500
# Date
# 2012-01-03       NaN       NaN       NaN       NaN       NaN
# 2012-01-04  0.023261  0.005360 -0.000449 -0.013264  0.000188
# 2012-01-05  0.010167  0.011041 -0.004201 -0.021522  0.002939
# 2012-01-06  0.015415  0.010400 -0.002408 -0.007773 -0.002540
# 2012-01-09 -0.013250 -0.001587  0.004211  0.012556  0.002259
# ...              ...       ...       ...       ...       ...
# 2023-03-30  0.012541  0.009841  0.004350  0.007195  0.005699
# 2023-03-31  0.014851  0.015523  0.008375  0.060504  0.014333
# 2023-04-03 -0.003718  0.007672  0.005500 -0.063119  0.003692
# 2023-04-04 -0.000174 -0.003255  0.004804 -0.011308 -0.005814
# 2023-04-05 -0.009938 -0.011355  0.006833 -0.037349 -0.002495
#
# [2833 rows x 5 columns]

# %%
for key, val in price_change_data.items():
    print(key)
    print("My JB Function:   ", jarque_bera_test(val))
    print("scipy JB Function:", jarque_bera(val)[:2])
# Out:
# MSFT
# 11.71977132246921 -0.21998156078720899 8994.901576811231
# My JB Function:    (8994.901576811231, 0.0)
# scipy JB Function: (8994.90157681113, 0.0)
# AAPL
# 8.717560970983726 -0.27814076802433274 3893.994407303274
# My JB Function:    (3893.994407303274, 0.0)
# scipy JB Function: (3893.9944073033244, 0.0)
# PG
# 15.017105782999689 -0.047754845086782835 17041.55451308515
# My JB Function:    (17041.55451308515, 0.0)
# scipy JB Function: (17041.554513085142, 0.0)
# TSLA
# 8.031301070242769 -0.048271371923042886 2988.150693376213
# My JB Function:    (2988.150693376213, 0.0)
# scipy JB Function: (2988.150693376209, 0.0)
# S&P500
# 19.305295865472267 -0.8015464523648662 31675.044454370254
# My JB Function:    (31675.044454370254, 0.0)
# scipy JB Function: (31675.04445437014, 0.0)

# %% [markdown]
# # Confidence Intervals

# %%
def t_quintile(df, alpha):
    q = (1.0 + alpha)/2
    a = stats.t.ppf(q, df)
    return a

# %%
t_quintile(len(sp500), 0.05)
# Out:
# 0.06273964329541434

# %%
def confidence_interval(data, alpha):
    n = len(data)
    df = n - 1
    x_bar = np.mean(data)
    SE = np.std(data) / np.sqrt(n)
    CI_quintile = t_quintile(df, alpha)
    CI = x_bar - CI_quintile * SE, x_bar + CI_quintile * SE
    return CI

# %%
sp500_CI = confidence_interval(sp500, 0.05)
sp500_CI
# Out:
# (0.006934593241426297, 0.007188368119346408)

# %%
sp500_yearly_CI = (1 + sp500_CI[0]) ** 12, (1 + sp500_CI[1]) ** 12
sp500_yearly_CI
# Out:
# (1.0864634873490415, 1.0897538656572028)

# %%
yearly_close_data = pd.DataFrame(close_data).resample("Y").first()
yearly_changes = np.log(yearly_close_data).diff()
yearly_changes
# Out:
#                AFMFX     AGTHX     AIVSX     AKRIX     AKRSX     AMCFX  \
# Date
# 1980-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 1981-12-31       NaN  0.373945       NaN       NaN       NaN       NaN
# 1982-12-31       NaN -0.020714       NaN       NaN       NaN       NaN
# 1983-12-31       NaN  0.192325       NaN       NaN       NaN       NaN
# 1984-12-31       NaN  0.207397       NaN       NaN       NaN       NaN
# 1985-12-31       NaN -0.087750       NaN       NaN       NaN       NaN
# 1986-12-31       NaN  0.171686       NaN       NaN       NaN       NaN
# 1987-12-31       NaN  0.112441  0.024667       NaN       NaN       NaN
# 1988-12-31       NaN  0.004728  0.002421       NaN       NaN       NaN
# 1989-12-31       NaN  0.094939  0.040432       NaN       NaN       NaN
# 1997-12-31  0.171705
# 1998-12-31  0.279877
# 1999-12-31  0.230745
# 2000-12-31  0.169689
# 2001-12-31 -0.125746
# 2002-12-31 -0.105597
# 2003-12-31 -0.239192
# 2004-12-31  0.198367
# 2005-12-31  0.081064
# 2006-12-31  0.054018
# 2007-12-31  0.110188
# 2008-12-31  0.021343
# 2009-12-31 -0.440240
# 2010-12-31  0.195497
# 2011-12-31  0.115628
# 2012-12-31  0.004072
# 2013-12-31  0.135532
# 2014-12-31  0.225305
# 2015-12-31  0.116434
# 2016-12-31 -0.022375
# 2017-12-31  0.114947
# 2018-12-31  0.177295
# 2019-12-31 -0.071404
#
# [40 rows x 101 columns]

# %%
yearly_return_CIs = confidence_interval(yearly_changes, 0.05)
fig, ax = plt.subplots(figsize = (10, 10))
Y_axis = np.arange(len(yearly_return_CIs[0]))

ax.hlines(y = Y_axis, xmin = yearly_return_CIs[0].sort_values(), xmax = yearly_return_CIs[1].sort_values() )
ax.vlines(x = [yearly_return_CIs[0]["S&P 500"],yearly_return_CIs[1]["S&P 500"]], ymin = 0, ymax = 100, label = "S&P 500 CI", color="r", linestyle="--")
ax.set_title("Various Mutual Fund's Confidence Intervals vs the S&P 500's Confidence Band")
ax.set_xlim(0.05)
ax.legend()
# Out:
# C:\Users\hthog\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %% [markdown]
# # ANOVA

# %%
mutual_fund_data[["Symbol", "Morningstar Category"]]
# Out:
#    Symbol Morningstar Category
# 0   AGTHX         Large Growth
# 1   FCNTX         Large Growth
# 2   CWMAX          Large Blend
# 3   CWMCX          Large Blend
# 4   CWMEX          Large Blend
# ..    ...                  ...
# 95  FDTRX         Large Growth
# 96  FDYZX         Large Growth
# 97  BBVLX          Large Value
# 98  PEYAX          Large Value
# 99  TWCGX         Large Growth
#
# [100 rows x 2 columns]

# %%
fund_types = mutual_fund_data["Morningstar Category"].value_counts() > 2
relevant_fund_types = fund_types[fund_types]
relevant_fund_types
# Out:
# Large Growth      True
# Large Value       True
# Large Blend       True
# Mid-Cap Growth    True
# Name: Morningstar Category, dtype: bool

# %%
# pull relevant funds, should kick out only 6 from the dataset
relevant_funds = mutual_fund_data[mutual_fund_data["Morningstar Category"].isin(relevant_fund_types.index)]
relevant_funds
# Out:
#    Symbol                                               Name  Category1  \
# 0   AGTHX  American Funds The Growth Fund of America Class A  US Equity
# 1   FCNTX                           Fidelity Contrafund Fund  US Equity
# 2   CWMAX  American Funds Washington Mutual Investors Fun...  US Equity
# 3   CWMCX  American Funds Washington Mutual Investors Fun...  US Equity
# 4   CWMEX  American Funds Washington Mutual Investors Fun...  US Equity
# ..    ...                                                ...        ...
# 95  FDTRX                    Franklin DynaTech Fund Class R6  US Equity
# 96  FDYZX               Franklin DynaTech Fund Advisor Class  US Equity
# 97  BBVLX                Bridge Builder Large Cap Value Fund  US Equity
# 98  PEYAX                Putnam Large Cap Value Fund Class A  US Equity
# 99  TWCGX        American Century Growth Fund Investor Class  US Equity
#
#        Category2  Category3 Morningstar Category  Morningstar Rating  \
# 0   Broad market  Large cap         Large Growth                 3.0
# 1   Broad market  Large cap         Large Growth                 3.0
# 2   Broad market  Large cap          Large Blend                 3.0
# 3   Broad market  Large cap          Large Blend                 3.0
# 4   Broad market  Large cap          Large Blend                 3.0
# ..           ...        ...                  ...                 ...
# 95  Broad market  Large cap         Large Growth                 5.0
# 96  Broad market  Large cap         Large Growth                 5.0
# 97  Broad market  Large cap          Large Value                 4.0
# 98  Broad market  Large cap          Large Value                 4.0
# 99  Broad market  Large cap         Large Growth                 3.0
#
#           Market cap Current yield   Fees   Action
# 0   $138,592,080,000         0.22%  0.62%  Analyze
# 1   $121,762,870,000         0.00%  0.74%  Analyze
# 2   $113,300,000,000         1.46%  0.63%  Analyze
# 3   $113,300,000,000         0.79%  1.40%  Analyze
# 4   $113,300,000,000         1.28%  0.87%  Analyze
# ..               ...           ...    ...      ...
# 95    $9,600,000,000         0.00%  0.51%  Analyze
# 96    $9,600,000,000         0.00%  0.62%  Analyze
# 97    $9,500,000,000         1.55%  0.25%  Analyze
# 98    $9,393,340,000         1.23%  0.91%  Analyze
# 99    $9,354,900,000         0.00%  0.98%  Analyze
#
# [94 rows x 11 columns]

# %%
relevant_fund_type_names = {}
for fund_type in relevant_fund_types.index:
    relevant_fund_type_names[fund_type] = relevant_funds["Symbol"][relevant_funds["Morningstar Category"] == fund_type]

# %%
for key in relevant_fund_type_names: 
    print(relevant_fund_type_names[key].head())
# Out:
# 0     AGTHX
# 1     FCNTX
# 9     AMCFX
# 10    CAFAX
# 11    CAFCX
# Name: Symbol, dtype: object
# 16    AFMFX
# 17    AMRFX
# 18    CMLAX
# 19    CMLCX
# 20    CMLEX
# Name: Symbol, dtype: object
# 2    CWMAX
# 3    CWMCX
# 4    CWMEX
# 5    CWMFX
# 6    AIVSX
# Name: Symbol, dtype: object
# 31    PRNHX
# 35    RPMGX
# 62    PCBIX
# 87    ERASX
# 88    ERSMX
# Name: Symbol, dtype: object

# %%
fund_type_returns = {}
for key in relevant_fund_type_names.keys():
    fund_type_returns[key] = []
    for val in relevant_fund_type_names[key]: 
        fund_type_returns[key].extend(monthly_returns[val].dropna())
[print(f"{key}: {np.mean(fund_type_returns[key])}") for key in fund_type_returns]
# Out:
# Large Growth: 0.008310739164947251
# Large Value: 0.007025138703066501
# Large Blend: 0.007410825346641584
# Mid-Cap Growth: 0.009292539985753287
# [None, None, None, None]

# %%
fig, axs = plt.subplots(1, 4 , figsize = (16, 4))
for num, key in enumerate(fund_type_returns): 
    series = pd.Series(fund_type_returns[key])
    axs[num].hist(fund_type_returns[key], bins = 50)
    axs[num].set_title(key)
    axs[num].set_yticks([])
    print("\nJB Test: " + str(jarque_bera_test(series)))
# Out:
# 7.306722341963728 -0.8882011536058676 11063.340003174764
#
# JB Test: (11063.340003174764, 0.0)
# 7.398926834447126 -0.9939036701083844 4477.855236680732
#
# JB Test: (4477.855236680732, 0.0)
# 6.459560813667616 -0.9327995659987388 2738.3389979112403
#
# JB Test: (2738.3389979112403, 0.0)
# 6.770051604399432 -0.7842229008782522 1042.0819583051461
#
# JB Test: (1042.0819583051461, 0.0)

# %% [markdown]
# # F Stats

# %%
def get_anova_counts(*args):
    k = len(args)
    N = 0
    for arg in args:
        N += len(arg)
    dfbn = k - 1
    dfwn = N - k

    return k, N, dfbn, dfwn

# %%
get_anova_counts(fund_type_returns["Large Growth"],
                 fund_type_returns['Large Value'],
                 fund_type_returns['Large Blend'],
                 fund_type_returns['Mid-Cap Growth'])
# Out:
# (4, 22600, 3, 22596)

# %%
def SSB(*args):
    ssb = 0
    alldata = np.concatenate(args)

    grand_mean = np.mean(alldata)

    for arg in args:
        group_mean = np.mean(arg)

        n = len(arg)
        val = n * (group_mean - grand_mean)**2

        ssb += val

    return ssb

# %%
SSB(fund_type_returns["Large Growth"], fund_type_returns['Large Value'],
    fund_type_returns['Large Blend'], fund_type_returns['Mid-Cap Growth'])
# Out:
# 0.009476529797051627

# %%
def SSW(*args):
    ssw = 0
    for arg in args: 
        group_mean = np.mean(arg)
        val = 0 
        for i in arg:
            val += np.sum(i - group_mean)**2
        ssw += val
    return ssw

# %%
SSW(fund_type_returns["Large Growth"],
               fund_type_returns['Large Value'],
               fund_type_returns['Large Blend'],
               fund_type_returns['Mid-Cap Growth'])
# Out:
# 52.14567979464993

# %%
def get_sum_square_stats(*args): 
    ssw = SSW(*args)
    ssb = SSB(*args)
    sst = ssb + ssw
    return ssw, ssb, sst

# %%
get_sum_square_stats(fund_type_returns["Large Growth"],
               fund_type_returns['Large Value'],
               fund_type_returns['Large Blend'],
               fund_type_returns['Mid-Cap Growth'])
# Out:
# (52.14567979464993, 0.009476529797051627, 52.15515632444698)

# %%
from scipy.stats import f as f_dist
def finish_anova(f, dfwn, dfbn): 
    # use scipy to plug f-value into f distribution to return p-value
     p_value =  1 - f_dist.cdf(f, dfwn, dfbn)
    
     if p_value > .05:
        return_string = "F-value: " + str(f) + ", P-value: " + str(
            p_value) + ", Fail to reject null hypothesis."
     else:
        return_string = "F-value: " + str(f) + ", P-value: " + str(
            round(p_value, 5)) + ", Reject null hypothesis."

     return return_string

# %%
def anova(*args):

    k, N, dfbn, dfwn  = get_anova_counts(*args)
    
    ssw, ssb, sst = get_sum_square_stats(*args)

    msb = ssb / dfbn
    msw = ssw / dfwn
    f = msb / msw

    return finish_anova(f, dfbn, dfwn)

# %%
anova(fund_type_returns["Large Growth"],
      fund_type_returns['Large Value'],
      fund_type_returns['Large Blend'],
      fund_type_returns['Mid-Cap Growth'])
# Out:
# 'F-value: 1.368804140869903, P-value: 0.25022968552308267, Fail to reject null hypothesis.'

# %%
#equivilent scipy function
stats.f_oneway(fund_type_returns["Large Growth"],
               fund_type_returns['Large Value'],
               fund_type_returns['Large Blend'],
               fund_type_returns['Mid-Cap Growth'])
# Out:
# F_onewayResult(statistic=1.3688041408699079, pvalue=0.2502296855231449)

# %% [markdown]
# ## Multiple Comparisons Procedure

# %%
fund_types_list = ["Large Growth", "Large Value", "Large Blend", "Mid-Cap Growth"]
for ftype in fund_types_list: 
    print(ftype+" mean: "+(str)(np.mean(fund_type_returns[ftype])))
# Out:
# Large Growth mean: 0.008310739164947251
# Large Value mean: 0.007025138703066501
# Large Blend mean: 0.007410825346641584
# Mid-Cap Growth mean: 0.009292539985753287

# %% [markdown]
# ## Bonferroni Correction

# %%
for ftype1 in fund_types_list: 
    for ftype2 in fund_types_list: 
        result = t_test(fund_type_returns[ftype1], fund_type_returns[ftype2], "independent")
        scipy_result = stats.ttest_ind(fund_type_returns[ftype1], fund_type_returns[ftype2])
        if("Reject" in result):
            print("\nftype1: " + ftype1 + "\nftype2: " + ftype2 + "\n" + result, scipy_result)
