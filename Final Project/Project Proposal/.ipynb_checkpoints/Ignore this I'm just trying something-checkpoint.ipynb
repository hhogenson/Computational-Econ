# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("DATA.csv")
data.head()
# Out:
#        Date        MGM       LVS      PENN       WYNN  UNEM       CPI  GDPCAP  \
# 0  1/3/2005  33.846539  32.35228  6.737508  36.172771   5.3  2.969762   50068
# 1  1/4/2005  33.586788  32.98585  6.612028  36.095520   5.3  2.969762   50068
# 2  1/5/2005  34.191269  32.57903  6.606376  36.503883   5.3  2.969762   50068
# 3  1/6/2005  36.217258  32.00549  6.720552  37.982792   5.3  2.969762   50068
# 4  1/7/2005  35.183014  30.37820  6.761248  36.719109   5.3  2.969762   50068
#
#      INT  RATE      PASS
# 0  12.51  5.81  65600443
# 1  12.51  5.81  65600443
# 2  12.51  5.81  65600443
# 3  12.51  5.77  65600443
# 4  12.51  5.77  65600443

# %%
data["Y30"] = data["WYNN"].shift(30)
data
# Out:
#            Date        MGM       LVS       PENN       WYNN  UNEM       CPI  \
# 0      1/3/2005  33.846539  32.35228   6.737508  36.172771   5.3  2.969762
# 1      1/4/2005  33.586788  32.98585   6.612028  36.095520   5.3  2.969762
# 2      1/5/2005  34.191269  32.57903   6.606376  36.503883   5.3  2.969762
# 3      1/6/2005  36.217258  32.00549   6.720552  37.982792   5.3  2.969762
# 4      1/7/2005  35.183014  30.37820   6.761248  36.719109   5.3  2.969762
# ...         ...        ...       ...        ...        ...   ...       ...
# 4399  6/24/2022  30.234806  33.43000  32.119999  58.290001   3.6  9.059758
# 4400  6/27/2022  30.024843  33.17000  32.320000  57.689999   3.6  9.059758
# 4401  6/28/2022  29.874868  34.51000  31.790001  59.509998   3.6  9.059758
# 4402  6/29/2022  29.164989  33.61000  31.139999  58.000000   3.6  9.059758
# 4403  6/30/2022  28.945030  33.59000  30.420000  56.980000   3.6  9.059758
#
#       GDPCAP    INT  RATE      PASS        Y30
# ...

# %%
X = np.array(data[["MGM", "LVS", "PENN", "UNEM", "CPI", "GDPCAP", "INT", "RATE", "PASS"]].loc[30:])
y = np.array(data[["WYNN"]].loc[30:])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
rf = RandomForestRegressor(n_estimators=1000, max_depth=20, random_state=0, verbose=2, max_features=3, bootstrap = True)
rf.fit(X_train, y_train)
# Out:
# C:\Users\hthog\AppData\Local\Temp\ipykernel_16020\1455063.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# building tree 1 of 1000
# building tree 2 of 1000
# building tree 3 of 1000
# building tree 4 of 1000
# building tree 5 of 1000
# building tree 6 of 1000
# building tree 7 of 1000
# building tree 8 of 1000
# building tree 9 of 1000
# building tree 10 of 1000
# building tree 11 of 1000
# building tree 12 of 1000
# building tree 13 of 1000
# building tree 14 of 1000
# building tree 15 of 1000
# building tree 16 of 1000
# building tree 17 of 1000
# building tree 18 of 1000
# building tree 19 of 1000
# building tree 20 of 1000
# building tree 21 of 1000
# building tree 22 of 1000
# building tree 23 of 1000
# building tree 24 of 1000
# building tree 25 of 1000
# ...

# %%
# evaluate the model
score = rf.score(X_test, y_test)
print("R^2 score: {:.2f}".format(score))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# R^2 score: 1.00
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished

# %%
results = []
for val in X:
    results.append(rf.predict(np.array(val).reshape(1, -1)))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# ...

# %%
data["Results"] = pd.DataFrame(results)
data
# Out:
#            Date        MGM       LVS       PENN       WYNN  UNEM       CPI  \
# 0      1/3/2005  33.846539  32.35228   6.737508  36.172771   5.3  2.969762
# 1      1/4/2005  33.586788  32.98585   6.612028  36.095520   5.3  2.969762
# 2      1/5/2005  34.191269  32.57903   6.606376  36.503883   5.3  2.969762
# 3      1/6/2005  36.217258  32.00549   6.720552  37.982792   5.3  2.969762
# 4      1/7/2005  35.183014  30.37820   6.761248  36.719109   5.3  2.969762
# ...         ...        ...       ...        ...        ...   ...       ...
# 4399  6/24/2022  30.234806  33.43000  32.119999  58.290001   3.6  9.059758
# 4400  6/27/2022  30.024843  33.17000  32.320000  57.689999   3.6  9.059758
# 4401  6/28/2022  29.874868  34.51000  31.790001  59.509998   3.6  9.059758
# 4402  6/29/2022  29.164989  33.61000  31.139999  58.000000   3.6  9.059758
# 4403  6/30/2022  28.945030  33.59000  30.420000  56.980000   3.6  9.059758
#
#       GDPCAP    INT  RATE      PASS        Y30    Results
# ...

# %%
fig, ax = plt.subplots(figsize=(40,20))
data[["WYNN"]].plot.line(ax=ax)
pd.DataFrame(results).plot.line(ax=ax)
# Out:
# <AxesSubplot: >

# %%
X_train[0]
# Out:
# array([7.88571850e+01, 7.69558900e+01, 1.33619720e+01, 5.00000000e+00,
#        4.08126858e+00, 5.20660000e+04, 1.27500000e+01, 6.11000000e+00,
#        7.07793010e+07])

# %%
X_test
# Out:
# array([[2.2857153e+01, 5.5634110e+01, 1.1400000e+01, ..., 1.1830000e+01,
#         4.3200000e+00, 7.1832889e+07],
#        [2.7871866e+01, 5.9294980e+01, 2.1030001e+01, ..., 1.5100000e+01,
#         3.7500000e+00, 8.9468183e+07],
#        [3.2467899e+01, 6.0490410e+01, 3.0790001e+01, ..., 1.3160000e+01,
#         3.9500000e+00, 8.2813260e+07],
#        ...,
#        [5.8370760e+00, 5.1486200e+00, 7.4406510e+00, ..., 1.2970000e+01,
#         4.8000000e+00, 6.5237061e+07],
#        [1.3950421e+01, 2.8137350e+01, 8.8627630e+00, ..., 1.2890000e+01,
#         4.5500000e+00, 6.8606237e+07],
#        [2.6880722e+01, 5.3048020e+01, 2.3820000e+01, ..., 1.4730000e+01,
#         4.5100000e+00, 8.6390799e+07]])

# %%
y_train
# Out:
# array([[ 70.588348],
#        [ 91.357681],
#        [ 53.540478],
#        ...,
#        [114.11264 ],
#        [ 99.332054],
#        [ 61.724308]])

# %%
y_test
# Out:
# array([[182.476105],
#        [115.173607],
#        [154.913406],
#        ...,
#        [ 23.574751],
#        [104.538696],
#        [109.824257]])

# %%
#IDK how much I trust that R^2 but whatevs ill look into it later
